# %% [markdown]
# # Exploratory analysis
# This notebook is intentionally thin. Reproducible data and feature logic lives in `src/ml_platform`, not notebook state.

# %%
from ml_platform.data.generate import generate_churn_data

df = generate_churn_data(5000, seed=42)
df.groupby("contract_type").churned.mean().sort_values(ascending=False)
